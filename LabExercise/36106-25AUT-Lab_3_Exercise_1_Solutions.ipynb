# %% [markdown]
# # **Lab 3: Categorical Data**

# %% [markdown]
#  ## Exercise 1:
#
# The dataset we will be using contains data related to second hand car sales. Your goal is to build a regression model with regularisation to predict accurately the sale price.
#
# You will be loading the dataset from this link:
# https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab03/ex1/car_details.csv
#
# The steps are:
#
# 1.   Load and Explore Dataset
# 2.   Data Preparation
# 3.   Split Datasets
# 4.   Assess Baseline Model
# 5.   Train Elastic Model

# %% [markdown]
# ---
# ### 0. Setup Environment

# %%
# Do not modify this code
# !pip install -q utstd

from utstd.folders import *
from utstd.ipyrenders import *

lab = LabExFolder(
  course_code="36106",
  lab="lab03",
  exercise="ex01"
)
lab.run()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.8 MB/s eta 0:00:00
# Mounted at /content/gdrive
#
# You can now save your data files in: /content/36106/labs/lab03/ex01/data

# %%
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### 1. Load and Explore Dataset

# %% [markdown]
# **[1.1]** Import the pandas, numpy and altair packages

# %%
# Placeholder for student's code

# %%
# Solution
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# **[1.2]** Create a variable called `file_url` containing the link to the CSV file

# %%
# Placeholder for student's code

# %%
# Solution
file_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab03/ex1/car_details.csv'

# %% [markdown]
# **[1.3]** Load the dataset into dataframe called `df`

# %%
# Placeholder for student's code

# %%
# Solution
df = pd.read_csv(file_url)
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %% [markdown]
# **[1.4]** Display the first 5 rows of `df`

# %%
# Placeholder for student's code

# %%
# Solution
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %% [markdown]
# **[1.5]** Display the last 5 rows of `df`

# %%
# Placeholder for student's code

# %%
# Solution
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %% [markdown]
# **[1.6]** Display the dimensions of `df`

# %%
# Placeholder for student's code

# %%
# Solution
df.shape
# Out:
# (4340, 8)

# %% [markdown]
# **[1.7]** Display the descriptive statistics of `df`

# %%
# Placeholder for student's code

# %%
# Solution
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %% [markdown]
# **[1.8]** Display the summary of `df`

# %%
# Placeholder for student's code

# %%
# Solution
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %% [markdown]
# ### 2. Data Preparation

# %% [markdown]
# **[2.1]** Create a copy of our dataframe called `df_cleaned`

# %%
# Placeholder for student's code

# %%
# Solution
df_cleaned = df.copy()
df_cleaned
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 0     Petrol  Individual       Manual   First Owner
# 1     Petrol  Individual       Manual   First Owner
# 2     Diesel  Individual       Manual   First Owner
# 3     Petrol  Individual       Manual   First Owner
# 4     Diesel  Individual       Manual  Second Owner
# ...      ...         ...          ...           ...
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 8 columns]

# %% [markdown]
# **[2.2]** Save all the columns names of `df` that are numerical type into a list called `num_cols`

# %%
# Placeholder for student's code

# %%
# Solution
num_cols = ['selling_price', 'year', 'km_driven']
num_cols
# Out:
# ['selling_price', 'year', 'km_driven']

# %% [markdown]
# **[2.3]** Save all the columns names of `df` that are ordinal type into a list called `ord_cols`

# %%
# Placeholder for student's code

# %%
# Solution
ord_cols = ['owner']
ord_cols
# Out:
# ['owner']

# %% [markdown]
# **[2.4]** Save all the columns names of `df` that are categorical type into a list called `cat_cols`

# %%
# Placeholder for student's code

# %%
# Solution
cat_cols = ['fuel', 'seller_type', 'transmission']
cat_cols
# Out:
# ['fuel', 'seller_type', 'transmission']

# %% [markdown]
# **[2.5]** Iterate through all columns from `ord_cols` and print their list of unique values

# %%
for col in ord_cols:
  print(col)
  print(df_cleaned[col].unique())
# Out:
# owner
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %% [markdown]
# **[2.6]** Create a dictionary mapping the values of `owner` column to an ordinal value

# %%
owner_mapper = {
    "Test Drive Car": 0,
    "First Owner": 1,
    "Second Owner": 2,
    "Third Owner": 3,
    "Fourth & Above Owner": 4
}
owner_mapper
# Out:
# {'Test Drive Car': 0,
#  'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth & Above Owner': 4}

# %% [markdown]
# **[2.7]** Replace the values of the `owner` column to their corresponsing ordinal value

# %%
df_cleaned["owner"] = df_cleaned["owner"].replace(owner_mapper)
df_cleaned["owner"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 4335    2
# 4336    2
# 4337    2
# 4338    1
# 4339    1
# Name: owner, Length: 4340, dtype: int64

# %% [markdown]
# **[2.8]** Iterate through all columns from `cat_cols` and print their list of unique values

# %%
# Placeholder for student's code

# %%
# Solution
for col in cat_cols:
  print(col)
  print(df_cleaned[col].unique())
# Out:
# fuel
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']
# seller_type
# ['Individual' 'Dealer' 'Trustmark Dealer']
# transmission
# ['Manual' 'Automatic']

# %% [markdown]
# **[2.9]** Perform one-hot encoding on all categorical columns and save them into a separate DataFrame called `df_cat`

# %%
df_cat = pd.get_dummies(df_cleaned[cat_cols])
df_cat
# Out:
#       fuel_CNG  fuel_Diesel  fuel_Electric  fuel_LPG  fuel_Petrol  \
# 0        False        False          False     False         True
# 1        False        False          False     False         True
# 2        False         True          False     False        False
# 3        False        False          False     False         True
# 4        False         True          False     False        False
# ...        ...          ...            ...       ...          ...
# 4335     False         True          False     False        False
# 4336     False         True          False     False        False
# 4337     False        False          False     False         True
# 4338     False         True          False     False        False
# 4339     False        False          False     False         True
#
#       seller_type_Dealer  seller_type_Individual  \
# 0                  False                    True
# 1                  False                    True
# 2                  False                    True
# 3                  False                    True
# 4                  False                    True
# ...                  ...                     ...
# 4335               False                    True
# 4336               False                    True
# 4337               False                    True
# 4338               False                    True
# 4339               False                    True
#
#       seller_type_Trustmark Dealer  transmission_Automatic  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                   False
# ...                            ...                     ...
# 4335                         False                   False
# 4336                         False                   False
# 4337                         False                   False
# 4338                         False                   False
# 4339                         False                   False
#
#       transmission_Manual
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True
# ...                   ...
# 4335                 True
# 4336                 True
# 4337                 True
# 4338                 True
# 4339                 True
#
# [4340 rows x 10 columns]

# %% [markdown]
# **[2.10]** Save all the numerical features (using `num_cols` and `ord_cols`) into a variable called `X`

# %%
# Placeholder for student's code

# %%
# Solution
X = df_cleaned[num_cols + ord_cols]
X
# Out:
#       selling_price  year  km_driven  owner
# 0             60000  2007      70000      1
# 1            135000  2007      50000      1
# 2            600000  2012     100000      1
# 3            250000  2017      46000      1
# 4            450000  2014     141000      2
# ...             ...   ...        ...    ...
# 4335         409999  2014      80000      2
# 4336         409999  2014      80000      2
# 4337         110000  2009      83000      2
# 4338         865000  2016      90000      1
# 4339         225000  2016      40000      1
#
# [4340 rows x 4 columns]

# %% [markdown]
# **[2.11]** Combine the one-hot encoded columns contained in `df_cat` into `X`

# %%
X = pd.concat([X, df_cat], axis=1)
X
# Out:
#       selling_price  year  km_driven  owner  fuel_CNG  fuel_Diesel  \
# 0             60000  2007      70000      1     False        False
# 1            135000  2007      50000      1     False        False
# 2            600000  2012     100000      1     False         True
# 3            250000  2017      46000      1     False        False
# 4            450000  2014     141000      2     False         True
# ...             ...   ...        ...    ...       ...          ...
# 4335         409999  2014      80000      2     False         True
# 4336         409999  2014      80000      2     False         True
# 4337         110000  2009      83000      2     False        False
# 4338         865000  2016      90000      1     False         True
# 4339         225000  2016      40000      1     False        False
#
#       fuel_Electric  fuel_LPG  fuel_Petrol  seller_type_Dealer  \
# 0             False     False         True               False
# 1             False     False         True               False
# 2             False     False        False               False
# 3             False     False         True               False
# 4             False     False        False               False
# ...             ...       ...          ...                 ...
# 4335          False     False        False               False
# 4336          False     False        False               False
# 4337          False     False         True               False
# 4338          False     False        False               False
# 4339          False     False         True               False
#
#       seller_type_Individual  seller_type_Trustmark Dealer  \
# 0                       True                         False
# 1                       True                         False
# 2                       True                         False
# 3                       True                         False
# 4                       True                         False
# ...                      ...                           ...
# 4335                    True                         False
# 4336                    True                         False
# 4337                    True                         False
# 4338                    True                         False
# 4339                    True                         False
#
#       transmission_Automatic  transmission_Manual
# 0                      False                 True
# 1                      False                 True
# 2                      False                 True
# 3                      False                 True
# 4                      False                 True
# ...                      ...                  ...
# 4335                   False                 True
# 4336                   False                 True
# 4337                   False                 True
# 4338                   False                 True
# 4339                   False                 True
#
# [4340 rows x 14 columns]

# %% [markdown]
# # 3. Split Datasets

# %% [markdown]
# **[3.1]** Extract the target variable into a variable called `y`
#
# Note: If you are stuck in previous steps, you can dowload the content of df_cleaned here: https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab03/ex1/df_cleaned.csv

# %%
# Placeholder for student's code

# %%
# Solution
y = X.pop('selling_price')
y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %% [markdown]
# **[3.2]** Create the test set (called `X_test` and `y_test`) by filtering rows only from the year 2018

# %%
# Placeholder for student's code

# %%
# Solution
test_mask = X['year'] == 2018
X_test = X[test_mask]
y_test = y[X_test.index]

# %% [markdown]
# **[3.3]** Create the validation set (called `X_val` and `y_val`) by filtering rows only from the year 2018

# %%
# Placeholder for student's code

# %%
# Solution
val_mask = X['year'] == 2017
X_val = X[val_mask]
y_val = y[X_val.index]

# %% [markdown]
# **[3.4]** Create the training set (called `X_train` and `y_train`) by keeping rows only prior to the year 2017

# %%
# Placeholder for student's code

# %%
# Solution
train_mask = X['year'] < 2017
X_train = X[train_mask]
y_train = y[X_train.index]

# %% [markdown]
# ### 4. Assess Baseline Model

# %% [markdown]
# **[4.1]** Import the DummyRegressor module from sklearn

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.dummy import DummyRegressor

# %% [markdown]
# **[4.2]** Instantiate the Dummy class into a variable called `base_reg` and fit it on the training set it

# %%
# Placeholder for student's code

# %%
# Solution
base_reg = DummyRegressor(strategy='mean')
base_reg.fit(X_train, y_train)
# Out:
# DummyRegressor()

# %% [markdown]
# **[4.3]** Import the RMSE and MAE from sklearn

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.metrics import root_mean_squared_error as rmse
from sklearn.metrics import mean_absolute_error as mae

# %% [markdown]
# **[4.4]** Display the RMSE and MAE scores of this baseline model

# %%
# Placeholder for student's code

# %%
# Solution
y_preds = base_reg.predict(X)
print(rmse(y, y_preds))
print(mae(y, y_preds))
# Out:
# 591029.3969839468
# 302061.0774092631

# %% [markdown]
# ### 5. Train Elastic Model

# %% [markdown]
# **[5.1]** Import the ElasticNet module from sklearn

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.linear_model import ElasticNet

# %% [markdown]
# **[5.2]** Instantiate the ElasticNet class into a variable called `elasticnet_reg` and fit it on the training set

# %%
# Placeholder for student's code

# %%
# Solution
elasticnet_reg = ElasticNet()
elasticnet_reg.fit(X_train, y_train)
# Out:
# ElasticNet()

# %% [markdown]
# **[5.3]** Use the trained model to predict the outcome on `X_train` and save the results into a variable called `y_preds`

# %%
# Placeholder for student's code

# %%
# Solution
y_train_preds = elasticnet_reg.predict(X_train)
y_train_preds
# Out:
# array([166605.11801523, 166495.67581157, 425068.10703136, ...,
#        223321.15732971, 562609.694984  , 476032.65008229])

# %% [markdown]
# **[5.4]** Display the RMSE and MAE scores on the training set

# %%
# Placeholder for student's code

# %%
# Solution
print(rmse(y_train, y_train_preds))
print(mae(y_train, y_train_preds))
# Out:
# 337505.51255903585
# 171499.4279835868

# %% [markdown]
# **[5.5]** Save the predictions on the validation set into a variable called `y_val_preds` and display the RMSE and MAE scores

# %%
# Placeholder for student's code

# %%
# Solution
y_val_preds = elasticnet_reg.predict(X_val)
print(rmse(y_val, y_val_preds))
print(mae(y_val, y_val_preds))
# Out:
# 659809.6641106856
# 321955.35210002173

# %% [markdown]
# **[5.6]** Display the predictions versus the target line charts on the training set

# %%
# Placeholder for student's code

# %%
# Solution
perfect_train = alt.Chart(pd.DataFrame({'target': y_train, 'preds': y_train})).mark_line(color='green').encode(
    x='target',
    y='preds'
)

pred_chart_train = alt.Chart(pd.DataFrame({'target': y_train, 'preds': y_train_preds})).mark_line().encode(
    x='target',
    y='preds'
  )

perfect_train + pred_chart_train
# Out:
# alt.LayerChart(...)

# %% [markdown]
# **[5.7]** Display the predictions versus the target line charts on the validation set

# %%
# Placeholder for student's code

# %%
# Solution
perfect_val = alt.Chart(pd.DataFrame({'target': y_val, 'preds': y_val})).mark_line(color='green').encode(
    x='target',
    y='preds'
)

pred_chart_val = alt.Chart(pd.DataFrame({'target': y_val, 'preds': y_val_preds})).mark_line().encode(
    x='target',
    y='preds'
  )

perfect_val + pred_chart_val
# Out:
# alt.LayerChart(...)
