# %% [markdown]
# # **Lab 4: Binary Classification**

# %% [markdown]
# ## Exercise 2: Feature Scaling
#
# In this exercise, you will train a binary classifier using SVM on the dataset used in the previous exercise. This time we will also perform feature scaling:
#
# You will have to import the dataset from the following link:
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_train.csv
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_val.csv
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_test.csv
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_train.csv
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_val.csv
# * https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_test.csv
#
# The steps are:
# 1.   Load dataset
# 2.   Feature Engineering
# 3.   Feature Scaling
# 4.   Train SVC
# 5.   Tune SVC with C Hyperparameter
# 6.   Tune SVC with gamma Hyperparameter
# 7.   Tune SVC with kernel Hyperparameter

# %% [markdown]
# ---
# ### 0. Setup Environment

# %%
# Do not modify this code
# !pip install -q utstd

from utstd.folders import *
from utstd.ipyrenders import *

lab = LabExFolder(
  course_code="36106",
  lab="lab04",
  exercise="ex02"
)
lab.run()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 14.4 MB/s eta 0:00:00
# Mounted at /content/gdrive
#
# You can now save your data files in: /content/36106/labs/lab04/ex02/data

# %%
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ## 1. Load and explore dataset

# %% [markdown]
# **[1.1]** Import the pandas and numpy packages

# %%
# Placeholder for student's code

# %%
# Solution
import pandas as pd
import numpy as np

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# **[1.2]** Create 4 variables containing the link to the CSV files

# %%
# Placeholder for student's code

# %%
# Solution
X_train_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_train.csv'
X_val_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_val.csv'
X_test_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/X_test.csv'
y_train_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_train.csv'
y_val_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_val.csv'
y_test_url = 'https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/y_test.csv'

# %% [markdown]
# **[1.3]** Load the different sets into separate dataframes

# %%
# Placeholder for student's code

# %%
# Solution
X_train = pd.read_csv(X_train_url)
X_val = pd.read_csv(X_val_url)
X_test = pd.read_csv(X_test_url)
y_train = pd.read_csv(y_train_url)
y_val = pd.read_csv(y_val_url)
y_test = pd.read_csv(y_test_url)

# %% [markdown]
# **[1.4]** Display the first 5 rows of X_train

# %%
# Placeholder for student's code

# %%
# Solution
X_train.head()
# Out:
#          date  min_temperature_c  max_temperature_c  rainfall_mm  \
# 0  2019-05-01               17.9               22.5          0.0
# 1  2019-05-02               19.5               24.1          0.0
# 2  2019-05-03               19.2               24.1          0.0
# 3  2019-05-04               17.3               23.1         10.8
# 4  2019-05-05               12.0               19.1          0.0
#
#    evaporation_mm  sunshine_hours  max_wind_speed_kmh  max_pressure_hpa  \
# 0             5.4             1.9                35.0            1022.6
# 1             3.4             1.7                33.0            1025.8
# 2             3.4             0.7                31.0            1019.1
# 3             2.4             5.8                39.0            1015.9
# 4             4.8             5.5                76.0            1017.6
#
#    rain_today
# 0           0
# 1           0
# 2           0
# 3           1
# 4           0

# %% [markdown]
# **[1.5]** Display the dimensions of each sets

# %%
# Placeholder for student's code

# %%
# Solution
print(X_train.shape)
print(X_val.shape)
print(X_test.shape)
print(y_train.shape)
print(y_val.shape)
print(y_test.shape)
# Out:
# (240, 9)
# (80, 9)
# (82, 9)
# (240, 1)
# (80, 1)
# (82, 1)

# %% [markdown]
# ## 2. Date Feature Engineering

# %% [markdown]
# **[2.1]** Convert the "**date**" column into a datetime for the training set

# %%
# Placeholder for student's code

# %%
# Solution
X_train['date'] = pd.to_datetime(X_train['date'])

# %% [markdown]
# **[2.2]** Convert the "**date**" column into a datetime for the validation and testing sets

# %%
# Placeholder for student's code

# %%
# Solution
X_val['date'] = pd.to_datetime(X_val['date'])
X_test['date'] = pd.to_datetime(X_test['date'])

# %% [markdown]
# **[2.3]** Create a new feature called `month` that will extract only the month component of the `date` column for all sets

# %%
# Placeholder for student's code

# %%
# Solution
X_train['month'] = X_train['date'].dt.month
X_val['month'] = X_val['date'].dt.month
X_test['month'] = X_test['date'].dt.month

# %% [markdown]
# **[2.4]** Create a new feature called `day` that will extract only the day of the month component of the `date` column for both all sets

# %%
# Placeholder for student's code

# %%
# Solution
X_train['day'] = X_train['date'].dt.day
X_val['day'] = X_val['date'].dt.day
X_test['day'] = X_test['date'].dt.day

# %% [markdown]
# **[2.5]** Create a new feature called `weekday` that will extract only the day of the week component of the `date` column for both all sets

# %%
# Placeholder for student's code

# %%
# Solution
X_train['weekday'] = X_train['date'].dt.weekday
X_val['weekday'] = X_val['date'].dt.weekday
X_test['weekday'] = X_test['date'].dt.weekday

# %% [markdown]
# **[2.6]** Remove the "**date**" column from all the sets

# %%
# Placeholder for student's code

# %%
# Solution
X_train.drop('date', axis=1, inplace=True)
X_val.drop('date', axis=1, inplace=True)
X_test.drop('date', axis=1, inplace=True)

# %% [markdown]
# ## 3. Feature Scaling
#
# Note: If you are stuck in previous steps, you can dowload the content of the prepared sets here: https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/

# %% [markdown]
# **[3.1]** Import StandardScaler from Sklearn

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **[3.2]** Instantiate a StandardScaler and save it into a variable called `scaler`

# %%
# Placeholder for student's code

# %%
# Solution
scaler = StandardScaler().set_output(transform="pandas")

# %% [markdown]
# **[3.3]** Fit the scaler on the training set

# %%
# Placeholder for student's code

# %%
# Solution
scaler.fit(X_train)
# Out:
# StandardScaler()

# %% [markdown]
# **[3.4]** Apply the scaler on the training set and display the result

# %%
# Placeholder for student's code

# %%
# Solution
scaler.transform(X_train)
# Out:
#      min_temperature_c  max_temperature_c  rainfall_mm  evaporation_mm  \
# 0             1.103683          -0.015977    -0.290380       -0.043366
# 1             1.485670           0.338656    -0.290380       -0.695895
# 2             1.414047           0.338656    -0.290380       -0.695895
# 3             0.960438           0.117010     1.595056       -1.022160
# 4            -0.304893          -0.769572    -0.290380       -0.239125
# ..                 ...                ...          ...             ...
# 235           1.987027           1.070086    -0.290380        3.415038
# 236           1.557292           0.560301    -0.290380        0.935428
# 237           1.652789           1.047922     0.163521       -0.500136
# 238           1.915405           1.203073     0.198436        0.021887
# 239           1.939279           0.914934    -0.255465        0.413404
#
#      sunshine_hours  max_wind_speed_kmh  max_pressure_hpa  rain_today  \
# ...

# %% [markdown]
# **[3.5]** Replace the features values with the results of the scaler

# %%
# Placeholder for student's code

# %%
# Solution
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## 4. Train SVM Classifier
#
# Note: If you are stuck in previous steps, you can dowload the content of the scaled sets here: https://raw.githubusercontent.com/aso-uts/labs_datasets/main/36106-mlaa/lab04/ex2/

# %% [markdown]
# **[4.1]** Import SVC from sklearn.svm

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.svm import SVC

# %% [markdown]
# **[4.2]** Instantiate our model

# %%
# Placeholder for student's code

# %%
# Solution
svc_1 = SVC()

# %% [markdown]
# **[4.3]** Fit our model with the training data

# %%
# Placeholder for student's code

# %%
# Solution
svc_1.fit(X_train, y_train)
# Out:
# SVC()

# %% [markdown]
# **[4.4]** Import the accuracy score from sklearn

# %%
# Placeholder for student's code

# %%
# Solution
from sklearn.metrics import accuracy_score

# %% [markdown]
# **[4.5]** Display the accuracy score for the training set

# %%
# Placeholder for student's code

# %%
# Solution
y_train_preds = svc_1.predict(X_train)
print(accuracy_score(y_train, y_train_preds))
# Out:
# 0.9041666666666667

# %% [markdown]
# **[4.6]** Display the accuracy score for the validation set

# %%
# Placeholder for student's code

# %%
# Solution
y_val_preds = svc_1.predict(X_val)
accuracy_score(y_val, y_val_preds)
# Out:
# 0.6125

# %% [markdown]
# ## 5. Tune SVC with C Hyperparameter

# %% [markdown]
# **[5.1]** Train a SVC model with the value 2 for `C`

# %%
# Placeholder for student's code

# %%
# Solution
svc_2 = SVC(C=2).fit(X_train, y_train)

# %% [markdown]
# **[5.2]** Display the accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
print(accuracy_score(y_train, svc_2.predict(X_train)))
print(accuracy_score(y_val, svc_2.predict(X_val)))
# Out:
# 0.9166666666666666
# 0.6125

# %% [markdown]
# **[5.3]** Train a SVC model with the value 0.4 for `C`

# %%
# Placeholder for student's code

# %%
# Solution
svc_3 = SVC(C=0.4).fit(X_train, y_train)

# %% [markdown]
# **[5.4]** Display the accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
print(accuracy_score(y_train, svc_3.predict(X_train)))
print(accuracy_score(y_val, svc_3.predict(X_val)))
# Out:
# 0.8791666666666667
# 0.6125

# %% [markdown]
# **[5.5]** Train a SVC model with the value 0.3 for `C` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_4 = SVC(C=0.3).fit(X_train, y_train)
print(accuracy_score(y_train, svc_4.predict(X_train)))
print(accuracy_score(y_val, svc_4.predict(X_val)))
# Out:
# 0.8666666666666667
# 0.6125

# %% [markdown]
# ## 6. Tune SVC with gamma Hyperparameter

# %% [markdown]
# **[6.1]** Train a SVC model with the value 0.1 for `gamma` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_5 = SVC(C=0.3, gamma=0.1).fit(X_train, y_train)
print(accuracy_score(y_train, svc_5.predict(X_train)))
print(accuracy_score(y_val, svc_5.predict(X_val)))
# Out:
# 0.8708333333333333
# 0.5875

# %% [markdown]
# **[6.2]** Train a SVC model with the value 0.01 for `gamma` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_6 = SVC(C=0.3, gamma=0.01).fit(X_train, y_train)
print(accuracy_score(y_train, svc_6.predict(X_train)))
print(accuracy_score(y_val, svc_6.predict(X_val)))
# Out:
# 0.8166666666666667
# 0.55

# %% [markdown]
# **[6.3]** Train a SVC model with the value 0.5 for `gamma` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_7 = SVC(C=0.3, gamma=0.5).fit(X_train, y_train)
print(accuracy_score(y_train, svc_7.predict(X_train)))
print(accuracy_score(y_val, svc_7.predict(X_val)))
# Out:
# 0.7583333333333333
# 0.4125

# %% [markdown]
# ## 7. Tune SVC with kernel Hyperparameter

# %% [markdown]
# **[7.1]** Train a SVC model with the value 'sigmoid' for `kernel` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_8 = SVC(C=0.3, gamma='scale', kernel='sigmoid').fit(X_train, y_train)
print(accuracy_score(y_train, svc_8.predict(X_train)))
print(accuracy_score(y_val, svc_8.predict(X_val)))
# Out:
# 0.8291666666666667
# 0.6375

# %% [markdown]
# **[7.2]** Train a SVC model with the value 'poly' for `kernel` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_9 = SVC(C=0.3, gamma='scale', kernel='poly').fit(X_train, y_train)
print(accuracy_score(y_train, svc_9.predict(X_train)))
print(accuracy_score(y_val, svc_9.predict(X_val)))
# Out:
# 0.8583333333333333
# 0.5625

# %% [markdown]
# **[7.3]** Train a SVC model with the value 'poly' for `kernel` and 5 as `degree` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_10 = SVC(C=0.3, gamma='scale', kernel='poly', degree=5).fit(X_train, y_train)
print(accuracy_score(y_train, svc_10.predict(X_train)))
print(accuracy_score(y_val, svc_10.predict(X_val)))
# Out:
# 0.875
# 0.5125

# %% [markdown]
# **[7.4]** Train a SVC model with the value 'poly' for `kernel` and 2 as `degree` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_11 = SVC(C=0.3, gamma='scale', kernel='poly', degree=2).fit(X_train, y_train)
print(accuracy_score(y_train, svc_11.predict(X_train)))
print(accuracy_score(y_val, svc_11.predict(X_val)))
# Out:
# 0.8333333333333334
# 0.575

# %% [markdown]
# **[7.5]** Train a SVC model with the value 'sigmoid' for `kernel` and 'balanced' for `class_weight` and display its accuracy score on the prediction from the training and validation sets

# %%
# Placeholder for student's code

# %%
# Solution
svc_new = SVC(C=0.3, gamma='scale', kernel='sigmoid', class_weight='balanced').fit(X_train, y_train)
print(accuracy_score(y_train, svc_new.predict(X_train)))
print(accuracy_score(y_val, svc_new.predict(X_val)))
# Out:
# 0.85
# 0.65
